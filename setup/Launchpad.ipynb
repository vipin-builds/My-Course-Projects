# %% [markdown]
# <a href="https://colab.research.google.com/github/vipin-builds/AI-Engineer-Core-Track/blob/main/setup/Launchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This notebook serves as the initial bridge between Google Colab and GitHub, establishing the development environment for my AI Engineer Core Track journey.

# %% [markdown]
# ## Hello GitHub

# %%
print("Link established!")

# %%
2+2
