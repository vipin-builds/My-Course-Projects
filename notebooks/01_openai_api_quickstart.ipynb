# %% [markdown]
# <a href="https://colab.research.google.com/github/vipin-builds/AI-Engineer-Core-Track/blob/main/notebooks/01_openai_api_quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Let's make the first Open AI API call. The same call would work with almost all models, except while instantiating the client object, we need to pass in extra parameters (base_url and api_key).
#
# ### For ex:
# ### gemini = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key="AZ...")

# %% [markdown]
# ## 🛠️ Step 1: Environment Setup & Authentication
#
# To securely run this notebook without exposing your credentials on GitHub, we use the **Google Colab Secrets Manager**.
#
# ### 🔑 Prerequisites
# 1. Open the **Secrets** (key icon 🔑) on the left sidebar.
# 2. Add a new secret with the Name: `OPENAI_API_KEY`.
# 3. Paste your [OpenAI API Key](https://platform.openai.com) into the Value field.
# 4. Toggle **Notebook access** to `ON`.

# %% [markdown]
# ## Get the API Key

# %%
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')

# %% [markdown]
# ### Set the API KEY to Google Colab environment

# %%
import os
from google.colab import userdata
from openai import OpenAI

# Securely retrieve the key from Colab Secrets
try:
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
    client = OpenAI()
    print("✅ OpenAI Client initialized successfully.")
except Exception as e:
    print("❌ Error: Make sure 'OPENAI_API_KEY' is set in the Secrets tab.")
# Out:
# ✅ OpenAI Client initialized successfully.

# %% [markdown]
# ### Use a small model

# %%
model = "gpt-5-nano"

# %% [markdown]
# ### Setup messages

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Hi"}
]

# %%
# Call Open AI

response = client.chat.completions.create(
    model=model, messages=messages
)

response.choices[0].message.content
# Out:
# 'Hi there! How can I help today? I can assist with explanations, writing, coding, math, planning, brainstorming, or just answer questions. \n\nA few quick ideas:\n- Explain a topic or concept\n- Draft or edit a message, essay, or code\n- Solve a math problem or debug code\n- Plan a trip, lesson, or project\n- Brainstorm ideas or summaries\n\nTell me what you’d like to do.'
